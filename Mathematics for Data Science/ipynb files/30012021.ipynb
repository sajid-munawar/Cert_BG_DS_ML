# %%
import numpy as np

# %%
np.random.uniform(1,10,10)
# Out:
# array([4.47355687, 4.88726458, 6.84194928, 3.17883939, 2.41142945,
#        3.03134271, 6.03496418, 8.98826036, 9.81812637, 4.60946605])

# %%
np.random.normal(2,5,10)
# Out:
# array([ 2.18008007,  1.42336672,  9.41504997, -4.00611434, -4.33488803,
#         6.30286359,  7.62090569, -1.17882158, -1.07905283, -2.05181447])

# %%
data = np.array([10,-5,20,30,60,70])

# %% [markdown]
# normalizing the data

# %%
normalized_data = (data - data.mean())/data.std()

# %%
normalized_data.std() #std dev. is 1
# Out:
# 1.0

# %%
normalized_data.mean() #mean is 0
# Out:
# 7.401486830834377e-17

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(np.arange(len(data)),data)

# %%
plt.plot(np.arange(len(normalized_data)),normalized_data)

# %%
plt.hist(data,5)
# Out:
# (array([1., 2., 1., 0., 2.]),
#  array([-5., 10., 25., 40., 55., 70.]),
#  <a list of 5 Patch objects>)

# %%
data = [0,2,4,9,10,30,-50]
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a992613748>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a992613470>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a99262c198>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a9925b7c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a9925b74a8>],
#  'means': []}

# %%
mid = [20,23,24,27,30,20]
final = [30,33,35,40,35,18]
plt.scatter(mid,final)

# %%
life = [65,60,50,45,43,40]
weight = [100,120,130,140,150,180]
plt.scatter(weight,life)
